# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
im = plt.imread('/Users/yizizhang/Downloads/monkey.jpg')

plt.imshow(im)
print(im.shape)
# Out:
# (604, 450, 3)

# %%
im.setflags(write=1)
im.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
im2 = im
print(im2.shape)
y = range(0,im2.shape[1])
im2[:, np.sin(y)<0,:] = 0   # where sin(y) < 0.7 is TRUE 
print(im2.max(), im2.min())

plt.imshow(im2)
# plt.savefig('img_with_occlusion_1.png')
# Out:
# (604, 450, 3)
# 255 0
