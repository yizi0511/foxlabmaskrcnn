# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
im = plt.imread('/Users/yizizhang/Desktop/foxlabmaskrcnn/flower.jpg')

plt.imshow(im)
print(im.shape)

im.setflags(write=1)
im.flags
# Out:
# (405, 720, 3)
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
vmask = im.copy()
print(vmask.shape)
y = range(0,vmask.shape[1])
vmask[:, np.sin(y)<0,:] = 0

plt.imshow(vmask)
# plt.savefig('img_with_occlusion_1.png')
# Out:
# (405, 720, 3)

# %%
hmask = vmask.copy()
print(hmask.shape)
x = range(0, hmask.shape[0])
y = range(0,hmask.shape[1])
hmask[np.sin(x)<0,:,:] = 0

plt.imshow(hmask)
# Out:
# (405, 720, 3)

# %%
im_mask = im.copy()

x = range(0, im_mask.shape[0])
y = range(0,im_mask.shape[1])
# im_mask = np.zeros((im3.shape[0], im3.shape[1]))

for i in x:
    for j in y:
        if np.sin((i+j)/10) < -.7:
            im_mask[i,j,:] = 0
        if np.sin((i-j)/10) < -.7:
            im_mask[i,j,:] = 0
        

masked_image = plt.imshow(im_mask)
# plt.colorbar()
# plt.ylim(100,120)
# plt.xlim(100,140)

# z[x,y] = np.sin((x+y)/2) < 0
# print(z)
# # w = np.sin(x-y)
# # im3[:,z,:] = 0
# print(im3.max(), im3.min())
# im3[x,y]=z
# plt.imshow(x,y,z)
